# %% [markdown]
# ### 0 - Modules and paths

# %%
import sys
from pathlib import Path

# add v1.1/ to sys.path for imports to work
sys.path.append(str(Path("..").resolve()))  # if notebook is in notebooks/

# import utils
import modules.yaml_utils as yu
import modules.graph as g

# important paths

ROOT = Path("..").resolve()
FILES = ROOT / "files"
INPUTS = FILES / "inputs"
GENERATED = FILES / "generated"

# %% [markdown]
# ### 1 - Test Graph

# %%
graph_yaml = INPUTS / "graph.yaml"

graph_dict = yu.load_file(graph_yaml)

graph = g.Graph(graph_dict)
sp = graph.shortest_path(31, 1)
sd = graph.distance(31, 1)
print("31 -> 1:") 
print(f"Distance: {sd}m")
print(f"Path: {sp}")
# Out:
# 31 -> 1:
# Distance: 0.859m
# Path: [31, 23, 16, 9, 1]
